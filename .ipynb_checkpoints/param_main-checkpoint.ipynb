# %%
import logging
from models import *
from train_lstm import *
from ax.service.managed_loop import optimize
import pickle


class ParamSearch:

    def __init__(self, x_train, y_train, x_validate, y_validate, epochs, batch_size=100):
        self.x_train = x_train
        self.y_train = y_train
        self.x_validate = x_validate
        self.y_validate = y_validate
        self.epochs = epochs

    def _train_eval(self, params: Dict[str, Union[str, bool, float, int, None]]) -> float:
        lstm = AutoRegressiveLinear(60, 12)
        lstm.cuda()
        train_silent(lstm, self.x_train, self.y_train, x_validate, y_validate, epochs=self.epochs, batch_size=100, **params)
        return evaluate(lstm, self.x_validate, self.y_validate)

    def run(self):
        best_parameters, values, experiment, model = optimize(
            minimize=True,
            parameters=[
                {"name": "lr", "type": "range", "bounds": [1e-5, 0.1], "log_scale": True},
                {"name": "gamma", "type": "range", "bounds": [0.99, 1.0], "log_scale": True},
            ],
            evaluation_function=self._train_eval,
            objective_name='mse',
            total_trials=30
        )
        print("Found best parameters: %s", best_parameters)
        return best_parameters, values, experiment, model

# %%
from src.train_lstm import *
from ax.plot.contour import plot_contour
from ax.utils.notebook.plotting import render, init_notebook_plotting

warmup = 10
x, y = load_dataset('data/simulations/2021-09-18_time_series.npz', warmup=10)
x_train, x_validate, x_test, y_train, y_validate, y_test = split_dataset_deterministic(x, y, 0.7, 0.2, 0.1)
x_train, x_validate, y_train, y_validate = to_torch(x_train, x_validate, y_train, y_validate)

s = ParamSearch(x_train, y_train, x_validate, y_validate, 15_000)
best_params, values, experiment, model = s.run()

print('=== BEST PARAMS ===')
print(best_params)

print('=== VALUES ===')
print(values)
# Out:
# [INFO 09-23 18:22:29] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter lr. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 09-23 18:22:29] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter lr_factor. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 09-23 18:22:29] ax.service.utils.instantiation: Inferred value type of ParameterType.INT for parameter patience. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 09-23 18:22:29] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+GPEI', steps=[Sobol for 5 trials, GPEI for subsequent trials]). Iterations after 5 will take longer to generate due to  model-fitting.
# [INFO 09-23 18:22:29] ax.service.managed_loop: Started full optimization with 20 steps.
# [INFO 09-23 18:22:29] ax.service.managed_loop: Running optimization trial 1...
# [INFO 09-23 18:24:57] ax.service.managed_loop: Running optimization trial 2...
# [INFO 09-23 18:27:25] ax.service.managed_loop: Running optimization trial 3...
# [INFO 09-23 18:30:32] ax.service.managed_loop: Running optimization trial 4...
# [INFO 09-23 18:34:37] ax.service.managed_loop: Running optimization trial 5...
# [INFO 09-23 18:41:11] ax.service.managed_loop: Running optimization trial 6...
# [INFO 09-23 18:43:37] ax.service.managed_loop: Running optimization trial 7...
# [INFO 09-23 18:46:04] ax.service.managed_loop: Running optimization trial 8...
# [INFO 09-23 18:48:29] ax.service.managed_loop: Running optimization trial 9...
# [INFO 09-23 18:50:55] ax.service.managed_loop: Running optimization trial 10...
# [INFO 09-23 18:53:24] ax.service.managed_loop: Running optimization trial 11...
# [INFO 09-23 18:55:51] ax.service.managed_loop: Running optimization trial 12...
# [INFO 09-23 18:58:17] ax.service.managed_loop: Running optimization trial 13...
# [INFO 09-23 19:00:43] ax.service.managed_loop: Running optimization trial 14...
# [INFO 09-23 19:04:03] ax.service.managed_loop: Running optimization trial 15...
# [INFO 09-23 19:06:21] ax.service.managed_loop: Running optimization trial 16...
# [INFO 09-23 19:08:40] ax.service.managed_loop: Running optimization trial 17...
# [INFO 09-23 19:10:57] ax.service.managed_loop: Running optimization trial 18...
# [INFO 09-23 19:13:16] ax.service.managed_loop: Running optimization trial 19...
# [INFO 09-23 19:15:33] ax.service.managed_loop: Running optimization trial 20...
# Found best parameters: %s {'lr': 0.0034983359266445467, 'lr_factor': 0.1, 'patience': 559}
# === BEST PARAMS ===
# {'lr': 0.0034983359266445467, 'lr_factor': 0.1, 'patience': 559}
# === VALUES ===
# ({'mse': -6.853216138486019}, {'mse': {'mse': 362.090570459379}})

# %%
render(plot_contour(model=model, param_x='lr', param_y='lr_factor', metric_name='mse'))
# Out:
# <div>                            <div id="d4ba947e-5481-4b8b-a816-78e05786583f" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d